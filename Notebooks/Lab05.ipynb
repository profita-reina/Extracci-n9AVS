# %% [markdown]
# # Datos Sintéticos
# ## Utilización de la libreria FAKER
# *Autor: Maria Reina Zarate Nava*

# %%
import pandas as pd
import numpy as np
import random

# %%
# Importamos la libreria Faker
from faker import Faker

# %%
# Creamos una instancia de Faker
fake = Faker("es_MX")

# %%
# Generamos datos sintéticos o datos falsos
datos = []
for i in range(100):
    datos.append(
        {
            "id_usuario": i +1,
            "nombre" :  fake.name(),
            "correo" : fake.email(),
            "edad" : random.randint(18,65),
            "seguidores" : random.randint(50,5000),
            "plataforma" : random.choice(["TikTok", "Instagram", "YouTube"])
        }
    )

# %%
dfInfluencer = pd.DataFrame(datos)

# %%
dfInfluencer
# Out:
#     id_usuario                              nombre  \
# 0            1                Timoteo Víctor Roque
# 1            2  Virginia Cecilia Laureano Rodrígez
# 2            3                    Esmeralda Aragón
# 3            4  Flavio Ricardo de la Rosa Palomino
# 4            5                         Susana Luna
# ..         ...                                 ...
# 95          96                 Hilda Rubio Montero
# 96          97              Carolina Munguía Cantú
# 97          98                 Lic. Oswaldo Nájera
# 98          99              Aurora Blanca Alvarado
# 99         100   Leonardo Gerardo Guerrero de León
#
#                         correo  edad  seguidores plataforma
# 0   espinalagustin@example.net    32        2885     TikTok
# 1       patricia99@example.org    23        1478    YouTube
# 2        paulina37@example.com    20        3511     TikTok
# 3        eugenio33@example.org    51        3179     TikTok
# 4    sandovaldulce@example.com    37        4261    YouTube
# ..                         ...   ...         ...        ...
# 95        andrea42@example.org    56        4180    YouTube
# 96           wruiz@example.org    36        4814    YouTube
# 97          tgodoy@example.org    59        3310  Instagram
# 98   blancasegovia@example.com    23         360    YouTube
# 99      graciela14@example.com    19        2639     TikTok
#
# [100 rows x 6 columns]

# %%
dfInfluencer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id_usuario  100 non-null    int64
#  1   nombre      100 non-null    object
#  2   correo      100 non-null    object
#  3   edad        100 non-null    int64
#  4   seguidores  100 non-null    int64
#  5   plataforma  100 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 4.8+ KB

# %%
dfInfluencer.describe()
# Out:
#        id_usuario        edad   seguidores
# count  100.000000  100.000000   100.000000
# mean    50.500000   40.540000  2699.730000
# std     29.011492   14.814285  1332.783295
# min      1.000000   18.000000   208.000000
# 25%     25.750000   28.000000  1595.500000
# 50%     50.500000   37.000000  2843.500000
# 75%     75.250000   57.000000  3723.750000
# max    100.000000   65.000000  4897.000000

# %%
dfInfluencer.describe(include="all")
# Out:
#         id_usuario                nombre                      correo  \
# count   100.000000                   100                         100
# unique         NaN                   100                         100
# top            NaN  Timoteo Víctor Roque  espinalagustin@example.net
# freq           NaN                     1                           1
# mean     50.500000                   NaN                         NaN
# std      29.011492                   NaN                         NaN
# min       1.000000                   NaN                         NaN
# 25%      25.750000                   NaN                         NaN
# 50%      50.500000                   NaN                         NaN
# 75%      75.250000                   NaN                         NaN
# max     100.000000                   NaN                         NaN
#
#               edad   seguidores plataforma
# count   100.000000   100.000000        100
# unique         NaN          NaN          3
# top            NaN          NaN    YouTube
# freq           NaN          NaN         38
# mean     40.540000  2699.730000        NaN
# std      14.814285  1332.783295        NaN
# min      18.000000   208.000000        NaN
# 25%      28.000000  1595.500000        NaN
# 50%      37.000000  2843.500000        NaN
# 75%      57.000000  3723.750000        NaN
# max      65.000000  4897.000000        NaN

# %%
# Graficar
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Graficamos como se generaron las edades
plt.figure(figsize = (8,4))
sns.histplot(dfInfluencer["edad"], bins=10)
plt.title("Distribución de edades")
plt.show()

# %%
# Graficamos la cantidad de usuarios por plataforma
plt.figure(figsize=(8,4))
sns.countplot(x="plataforma", data = dfInfluencer)
plt.title("Cantidad de usuarios por plataforma")
plt.show()
